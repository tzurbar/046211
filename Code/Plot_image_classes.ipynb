# %% [markdown]
# <a href="https://colab.research.google.com/github/tzurbar/046211/blob/main/Code/Plot_image_classes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
import random
import matplotlib.image as mpimg
from PIL import Image
import matplotlib.pyplot as plt

# Mount Google Drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Define the path to your image folders
base_dir = '/content/drive/MyDrive/046211/Project'

# Define the size for resizing
resize_size = (128, 128)  # Change this to your desired size

# List all subdirectories (each folder represents a label)
subdirs = [d for d in os.listdir(base_dir) if os.path.isdir(os.path.join(base_dir, d))]

# Randomly select one image from each folder
images = []
labels = []
for subdir in subdirs:
    folder_path = os.path.join(base_dir, subdir)
    image_files = [f for f in os.listdir(folder_path) if f.lower().endswith(('.png', '.jpg', '.jpeg'))]
    if image_files:
        image_file = random.choice(image_files)
        img_path = os.path.join(folder_path, image_file)
        img = Image.open(img_path).resize(resize_size)  # Resize image
        images.append(img)
        labels.append(subdir)

# Plot the images
fig, axes = plt.subplots(2, 5, figsize=(20, 8))  # Adjust the figsize for better spacing
for ax, img, label in zip(axes.flatten(), images, labels):
    ax.imshow(img)
    ax.set_title(label, fontsize=10)  # Adjust fontsize as needed
    ax.axis('off')

plt.tight_layout(pad=2.0)  # Increase padding to avoid overlap
plt.savefig('/content/drive/MyDrive/046211/Project/Plot_classes.png')
plt.show()
